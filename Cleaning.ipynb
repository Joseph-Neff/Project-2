# %%
import pandas as pd
from sqlalchemy import create_engine

# %%
yearly_file = "./Resources/Prices by Year.csv"
yearly_df = pd.read_csv(yearly_file)
yearly_df.head()
# Out:
#   service_category  year  age_band  sex  spending_per_person  \
# 0               PH  2015         1  F                1102.14
# 1               PH  2016         1  F                1139.87
# 2               PH  2017         1  F                1180.43
# 3               PH  2018         1  F                1196.93
# 4               PH  2019         1  F                1237.09
#
#    out_of_pocket_spending_per_person  utilization_per_1000_people  price  \
# 0                             218.83                     12264.20  89.87
# 1                             230.63                     12366.18  92.18
# 2                             243.11                     12530.87  94.20
# 3                             259.81                     12664.82  94.51
# 4                             266.36                     12664.00  97.69
#
#    out_of_pocket_price  share_of_annual_enrollment
# 0                17.84                      0.1184
# 1                18.65                      0.1184
# 2                19.40                      0.1186
# 3                20.51                      0.1193
# 4                21.03                      0.1192

# %%
new_yearly_df = yearly_df[["year", "service_category", "sex", "spending_per_person", "out_of_pocket_spending_per_person", "price", "out_of_pocket_price"]].copy()
new_yearly_df.head()
# Out:
#    year service_category  sex  spending_per_person  \
# 0  2015               PH  F                1102.14
# 1  2016               PH  F                1139.87
# 2  2017               PH  F                1180.43
# 3  2018               PH  F                1196.93
# 4  2019               PH  F                1237.09
#
#    out_of_pocket_spending_per_person  price  out_of_pocket_price
# 0                             218.83  89.87                17.84
# 1                             230.63  92.18                18.65
# 2                             243.11  94.20                19.40
# 3                             259.81  94.51                20.51
# 4                             266.36  97.69                21.03

# %%
one_year_file = "./Resources/Single Year Data.csv"
one_year_df = pd.read_csv(one_year_file)
one_year_df.head()
new_one_yr_df = one_year_df.reset_index()
new_one_yr_df.head()

updated_df = new_one_yr_df.rename(columns={'level_0': 'age', 'level_1': 'sex', 'level_2' : 'bmi', 'level_3' : 'children', 'level_4' : 'smoker', 'level_5' : 'region'})
updated_df.head()

one_year_df = updated_df.drop(index=0)
one_year_df.head()
# Out:
#   age     sex     bmi children smoker     region    insurance
# 1  19  female    27.9        0    yes  southwest    16884.924
# 2  18    male   33.77        1     no  southeast    1725.5523
# 3  28    male      33        3     no  southeast     4449.462
# 4  33    male  22.705        0     no  northwest  21984.47061
# 5  32    male   28.88        0     no  northwest    3866.8552

# %%
connection_string = "postgres:postgres@localhost:5432/Insurance_db"
engine = create_engine(f'postgresql://{connection_string}')

# %%
engine.table_names()
# Out:
# /var/folders/w4/cz88rjkj0lg25jggxn27s8l40000gn/T/ipykernel_60590/4162273999.py:1: SADeprecationWarning: The Engine.table_names() method is deprecated and will be removed in a future release.  Please refer to Inspector.get_table_names(). (deprecated since: 1.4)
#   engine.table_names()
# ['yearly_rates', 'one_year']

# %%
new_yearly_df.to_sql(name='yearly_rates', con=engine, if_exists='append', index=False)

# %%
one_year_df.to_sql(name='one_year', con=engine, if_exists='append', index=False)
# Out:
# ---------------------------------------------------------------------------
# InvalidTextRepresentation                 Traceback (most recent call last)
# ~/opt/anaconda3/lib/python3.9/site-packages/sqlalchemy/engine/base.py in _execute_context(self, dialect, constructor, statement, parameters, execution_options, *args, **kw)
#    1750                 if not evt_handled:
# -> 1751                     self.dialect.do_executemany(
#    1752                         cursor, statement, parameters, context
#
# ~/opt/anaconda3/lib/python3.9/site-packages/sqlalchemy/dialects/postgresql/psycopg2.py in do_executemany(self, cursor, statement, parameters, context)
#     961             xtras = self._psycopg2_extras()
# --> 962             context._psycopg2_fetched_rows = xtras.execute_values(
#     963                 cursor,
#
# ~/opt/anaconda3/lib/python3.9/site-packages/psycopg2/extras.py in execute_values(cur, sql, argslist, template, page_size, fetch)
#    1269         parts[-1:] = post
# -> 1270         cur.execute(b''.join(parts))
#    1271         if fetch:
#
# InvalidTextRepresentation: invalid input syntax for type integer: "16884.924"
# LINE 1: ...('19', 'female', '27.9', '0', 'yes', 'southwest', '16884.924...
#                                                              ^
#
#
# The above exception was the direct cause of the following exception:
#
# DataError                                 Traceback (most recent call last)
# /var/folders/w4/cz88rjkj0lg25jggxn27s8l40000gn/T/ipykernel_60590/918388771.py in <module>
# ----> 1 one_year_df.to_sql(name='one_year', con=engine, if_exists='append', index=False)
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/generic.py in to_sql(self, name, con, schema, if_exists, index, index_label, chunksize, dtype, method)
#    2870         from pandas.io import sql
#    2871
# -> 2872         sql.to_sql(
#    2873             self,
#    2874             name,
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/io/sql.py in to_sql(frame, name, con, schema, if_exists, index, index_label, chunksize, dtype, method, engine, **engine_kwargs)
#     715         )
#     716
# --> 717     pandas_sql.to_sql(
#     718         frame,
#     719         name,
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/io/sql.py in to_sql(self, frame, name, if_exists, index, index_label, schema, chunksize, dtype, method, engine, **engine_kwargs)
#    1759         )
#    1760
# -> 1761         sql_engine.insert_records(
#    1762             table=table,
#    1763             con=self.connectable,
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/io/sql.py in insert_records(self, table, con, frame, name, index, schema, chunksize, method, **engine_kwargs)
#    1348                 raise ValueError("inf cannot be used with MySQL") from err
#    1349             else:
# -> 1350                 raise err
#    1351
#    1352
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/io/sql.py in insert_records(self, table, con, frame, name, index, schema, chunksize, method, **engine_kwargs)
#    1338
#    1339         try:
# -> 1340             table.insert(chunksize=chunksize, method=method)
#    1341         except exc.SQLAlchemyError as err:
#    1342             # GH34431
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/io/sql.py in insert(self, chunksize, method)
#     965
#     966                 chunk_iter = zip(*[arr[start_i:end_i] for arr in data_list])
# --> 967                 exec_insert(conn, keys, chunk_iter)
#     968
#     969     def _query_iterator(
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/io/sql.py in _execute_insert(self, conn, keys, data_iter)
#     880         """
#     881         data = [dict(zip(keys, row)) for row in data_iter]
# --> 882         conn.execute(self.table.insert(), data)
#     883
#     884     def _execute_insert_multi(self, conn, keys: list[str], data_iter):
#
# ~/opt/anaconda3/lib/python3.9/site-packages/sqlalchemy/engine/base.py in execute(self, statement, *multiparams, **params)
#    1261             )
#    1262         else:
# -> 1263             return meth(self, multiparams, params, _EMPTY_EXECUTION_OPTS)
#    1264
#    1265     def _execute_function(self, func, multiparams, params, execution_options):
#
# ~/opt/anaconda3/lib/python3.9/site-packages/sqlalchemy/sql/elements.py in _execute_on_connection(self, connection, multiparams, params, execution_options, _force)
#     321     ):
#     322         if _force or self.supports_execution:
# --> 323             return connection._execute_clauseelement(
#     324                 self, multiparams, params, execution_options
#     325             )
#
# ~/opt/anaconda3/lib/python3.9/site-packages/sqlalchemy/engine/base.py in _execute_clauseelement(self, elem, multiparams, params, execution_options)
#    1450             linting=self.dialect.compiler_linting | compiler.WARN_LINTING,
#    1451         )
# -> 1452         ret = self._execute_context(
#    1453             dialect,
#    1454             dialect.execution_ctx_cls._init_compiled,
#
# ~/opt/anaconda3/lib/python3.9/site-packages/sqlalchemy/engine/base.py in _execute_context(self, dialect, constructor, statement, parameters, execution_options, *args, **kw)
#    1812
#    1813         except BaseException as e:
# -> 1814             self._handle_dbapi_exception(
#    1815                 e, statement, parameters, cursor, context
#    1816             )
#
# ~/opt/anaconda3/lib/python3.9/site-packages/sqlalchemy/engine/base.py in _handle_dbapi_exception(self, e, statement, parameters, cursor, context)
#    1993                 util.raise_(newraise, with_traceback=exc_info[2], from_=e)
#    1994             elif should_wrap:
# -> 1995                 util.raise_(
#    1996                     sqlalchemy_exception, with_traceback=exc_info[2], from_=e
#    1997                 )
#
# ~/opt/anaconda3/lib/python3.9/site-packages/sqlalchemy/util/compat.py in raise_(***failed resolving arguments***)
#     205
#     206         try:
# --> 207             raise exception
#     208         finally:
#     209             # credit to
#
# ~/opt/anaconda3/lib/python3.9/site-packages/sqlalchemy/engine/base.py in _execute_context(self, dialect, constructor, statement, parameters, execution_options, *args, **kw)
#    1749                             break
#    1750                 if not evt_handled:
# -> 1751                     self.dialect.do_executemany(
#    1752                         cursor, statement, parameters, context
#    1753                     )
#
# ~/opt/anaconda3/lib/python3.9/site-packages/sqlalchemy/dialects/postgresql/psycopg2.py in do_executemany(self, cursor, statement, parameters, context)
#     960                 kwargs = {}
#     961             xtras = self._psycopg2_extras()
# --> 962             context._psycopg2_fetched_rows = xtras.execute_values(
#     963                 cursor,
#     964                 statement,
#
# ~/opt/anaconda3/lib/python3.9/site-packages/psycopg2/extras.py in execute_values(cur, sql, argslist, template, page_size, fetch)
#    1268             parts.append(b',')
#    1269         parts[-1:] = post
# -> 1270         cur.execute(b''.join(parts))
#    1271         if fetch:
#    1272             result.extend(cur.fetchall())
#
# DataError: (psycopg2.errors.InvalidTextRepresentation) invalid input syntax for type integer: "16884.924"
# LINE 1: ...('19', 'female', '27.9', '0', 'yes', 'southwest', '16884.924...
#                                                              ^
#
# [SQL: INSERT INTO one_year (age, sex, bmi, children, smoker, region, insurance) VALUES (%(age)s, %(sex)s, %(bmi)s, %(children)s, %(smoker)s, %(region)s, %(insurance)s)]
# [parameters: ({'age': '19', 'sex': 'female', 'bmi': '27.9', 'children': '0', 'smoker': 'yes', 'region': 'southwest', 'insurance': '16884.924'}, {'age': '18', 'sex': 'male', 'bmi': '33.77', 'children': '1', 'smoker': 'no', 'region': 'southeast', 'insurance': '1725.5523'}, {'age': '28', 'sex': 'male', 'bmi': '33', 'children': '3', 'smoker': 'no', 'region': 'southeast', 'insurance': '4449.462'}, {'age': '33', 'sex': 'male', 'bmi': '22.705', 'children': '0', 'smoker': 'no', 'region': 'northwest', 'insurance': '21984.47061'}, {'age': '32', 'sex': 'male', 'bmi': '28.88', 'children': '0', 'smoker': 'no', 'region': 'northwest', 'insurance': '3866.8552'}, {'age': '31', 'sex': 'female', 'bmi': '25.74', 'children': '0', 'smoker': 'no', 'region': 'southeast', 'insurance': '3756.6216'}, {'age': '46', 'sex': 'female', 'bmi': '33.44', 'children': '1', 'smoker': 'no', 'region': 'southeast', 'insurance': '8240.5896'}, {'age': '37', 'sex': 'female', 'bmi': '27.74', 'children': '3', 'smoker': 'no', 'region': 'northwest', 'insurance': '7281.5056'}  ... displaying 10 of 1338 total bound parameter sets ...  {'age': '21', 'sex': 'female', 'bmi': '25.8', 'children': '0', 'smoker': 'no', 'region': 'southwest', 'insurance': '2007.945'}, {'age': '61', 'sex': 'female', 'bmi': '29.07', 'children': '0', 'smoker': 'yes', 'region': 'northwest', 'insurance': '29141.3603'})]
# (Background on this error at: https://sqlalche.me/e/14/9h9h)
